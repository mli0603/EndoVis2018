# %%
# This code is used for JHU CS 482/682: Deep Learning 2019 Spring Project
# Copyright: Zhaoshuo Li, Ding Hao, Mingyi Zheng
# !pip install tensorboardX visdom image_slicer
import os

import torch
import torchvision
from torch import nn
from torch.autograd import Variable
import torch.nn.functional as functional
from torch.utils.data import DataLoader, Dataset
#from torchvision import transforms
import torchvision.transforms.functional as TF

import copy
import numpy as np
import random
from tensorboardX import SummaryWriter

import transforms
from dataset import *
from visualization import *
from label_conversion import *
from dice_loss import *
from model_trainning import *
from model_from_ternaus import *
from unet import *

from google.colab import drive
drive.mount('/mydrive')
# Out:
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.6/dist-packages (1.6)
# Requirement already satisfied: visdom in /usr/local/lib/python3.6/dist-packages (0.1.8.8)
# Requirement already satisfied: image_slicer in /usr/local/lib/python3.6/dist-packages (0.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.12.0)
# Requirement already satisfied: protobuf>=3.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.16.3)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from visdom) (4.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from visdom) (2.21.0)
# Requirement already satisfied: torchfile in /usr/local/lib/python3.6/dist-packages (from visdom) (0.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from visdom) (1.2.1)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.6/dist-packages (from visdom) (17.0.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.6/dist-packages (from visdom) (0.56.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from visdom) (4.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.2.0->tensorboardX) (41.0.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->visdom) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->visdom) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->visdom) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->visdom) (2.8)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->visdom) (0.46)
# Drive already mounted at /mydrive; to attempt to forcibly remount, call drive.mount("/mydrive", force_remount=True).

# %%
# os.environ["CUDA_VISIBLE_DEVICES"]="2"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device("cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cuda

# %% [markdown]
# # Seed pytorch and numpy and random

# %%
# IMPORTANT!
# must seed the same value each time when training a new network
seed = 256
random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
pretrain_seed = 128

# %% [markdown]
# ## Hyperparameters

# %%
train_batch_size = 10
validation_batch_size=10
learning_rate = 0.001
num_epochs = 50
num_class = 12
num_superclasses = 2
super2sub = [[0,4,5,6,10],[1,2,3,7,8,9,11]]
num_filters = 64

# %%
#dice_loss = BatchWeightDICELoss()
weights = torch.ones((num_class,1)).to(device = device)
dice_loss = SuperLabelDICELoss(weights,_lambda=0.2) 
# dice_loss = DICELoss(weights)

# %% [markdown]
# ## Visualization

# %%
# Initialize the visualization environment
writer = SummaryWriter()

# %% [markdown]
# ## Unet

# %%
#initialize model
model = SuperLabelAlbuNet(num_super_class = num_superclasses,num_classes = num_class,num_filters = num_filters, pretrained = True, is_deconv = True, super2sub=super2sub)
model_dict = model.state_dict()
# pretrained_dict = torch.load("/mydrive/My Drive/Colab Notebooks/trained_albunet.pt")
# pretrained_dict = {k: v for k, v in pretrained_dict.items() if (k in model_dict and "final" not in k)}
# 2. overwrite entries in the existing state dict
# model_dict.update(pretrained_dict) 
# 3. load the new state dict
# model.load_state_dict(model_dict)
# freeze the pretrained feature.
# for param in model.parameters():
#     param.requires_grad = False
# for param in model.super_class_classifier.parameters():
#     param.requires_grad = True
# for param in model.final_classifier.parameters():
#     param.requires_grad = True
# model = AlbuNet(num_classes = num_class,num_filters = num_filters, pretrained = True, is_deconv = True)
model.to(device)
# Out:
# SuperLabelAlbuNet(
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (encoder): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=1000, bias=True)
#   )
#   (relu): ReLU(inplace)
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (conv5): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (center): DecoderBlock(
#     (block): Sequential(
#       (0): ConvRelu(
#         (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU(inplace)
#       )
#       (1): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (2): ReLU(inplace)
#     )
#   )
#   (dec5): DecoderBlock(
#     (block): Sequential(
#       (0): ConvRelu(
#         (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU(inplace)
#       )
#       (1): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (2): ReLU(inplace)
#     )
#   )
#   (dec4): DecoderBlock(
#     (block): Sequential(
#       (0): ConvRelu(
#         (conv): Conv2d(768, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU(inplace)
#       )
#       (1): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (2): ReLU(inplace)
#     )
#   )
#   (dec3): DecoderBlock(
#     (block): Sequential(
#       (0): ConvRelu(
#         (conv): Conv2d(640, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU(inplace)
#       )
#       (1): ConvTranspose2d(512, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (2): ReLU(inplace)
#     )
#   )
#   (dec2): DecoderBlock(
#     (block): Sequential(
#       (0): ConvRelu(
#         (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU(inplace)
#       )
#       (1): ConvTranspose2d(256, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (2): ReLU(inplace)
#     )
#   )
#   (dec1): DecoderBlock(
#     (block): Sequential(
#       (0): ConvRelu(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU(inplace)
#       )
#       (1): ConvTranspose2d(256, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (2): ReLU(inplace)
#     )
#   )
#   (dec0): ConvRelu(
#     (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU(inplace)
#   )
#   (super_class_classifier): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#   (final_classifier): Conv2d(64, 12, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# ## Optimizer and Scheduler and loss

# %%
# intialize optimizer and lr decay
optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.95)

# %% [markdown]
# ## Baseline Unet16 (unet with vgg16 backbone not pretrained), without augmentation.

# %%
# IMPORTANT!
# must seed the same value each time when training a new network
seed = 256
random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)

# %%
# define transform
train_dataset=MICCAIDataset(data_path = "/mydrive/My Drive/Colab Notebooks/data/",data_type = "train", transform=None)
validation_dataset=MICCAIDataset(data_path = "/mydrive/My Drive/Colab Notebooks/data/",data_type = "validation", transform=None)
label_converter = LabelConverter(data_path = "/mydrive/My Drive/Colab Notebooks/data/")

# # show one example
img,label = (train_dataset[0]['img'],train_dataset[0]['label'])
imshow(img.permute(1,2,0),denormalize=True)
colorlabel = train_dataset.label_converter.label2color(label.permute(1,2,0))
imshow(colorlabel)

# show one example
img,label = (validation_dataset[0]['img'],validation_dataset[0]['label'])
imshow(img.permute(1,2,0),denormalize=True)
colorlabel = train_dataset.label_converter.label2color(label.permute(1,2,0))
imshow(colorlabel)

# %%
# intialize the dataloader
train_generator = DataLoader(train_dataset,shuffle=True,batch_size=train_batch_size,num_workers=8)
validation_generator = DataLoader(validation_dataset,shuffle=True,batch_size=validation_batch_size,num_workers=8)

# %% [markdown]
# ## Start training

# %%
best_model_wts, best_acc = run_training(model,device,num_class,scheduler,optimizer,dice_loss,num_epochs,train_generator,train_dataset,validation_generator,validation_dataset,writer)
# Out:
# Training Started!
#
# EPOCH 1 of 50
#
# Training Loss: 0.8854
# 0 Class, True Pos 43984664.0, False Pos 35620952.0, False Neg 9159443.0, Dice score 0.66
# 1 Class, True Pos 9573330.0, False Pos 4949716.0, False Neg 1347518.0, Dice score 0.75
# 2 Class, True Pos 3453953.0, False Pos 4467144.0, False Neg 1898748.0, Dice score 0.52
# 3 Class, True Pos 301841.0, False Pos 810359.0, False Neg 2175519.0, Dice score 0.17
# 4 Class, True Pos 794165.0, False Pos 3006997.0, False Neg 19265698.0, Dice score 0.07
# 5 Class, True Pos 2704285.0, False Pos 5163243.0, False Neg 10991813.0, Dice score 0.25
# 6 Class, True Pos 1031.0, False Pos 344491.0, False Neg 417588.0, Dice score 0.00
# 7 Class, True Pos 12744.0, False Pos 1013620.0, False Neg 600558.0, Dice score 0.02
# 8 Class, True Pos 1.0, False Pos 287499.0, False Neg 4191.0, Dice score 0.00
# 9 Class, True Pos 4135.0, False Pos 648962.0, False Neg 483381.0, Dice score 0.01
# 10 Class, True Pos 3236.0, False Pos 38689.0, False Neg 9488232.0, Dice score 0.00
# 11 Class, True Pos 254.0, False Pos 42215.0, False Neg 561192.0, Dice score 0.00
# Vaildation Loss: 0.8910
# 0 Class, True Pos 10222444.0, False Pos 7344147.0, False Neg 2903059.0, Dice score 0.67
# 1 Class, True Pos 2039181.0, False Pos 3132723.0, False Neg 497723.0, Dice score 0.53
# 2 Class, True Pos 1160749.0, False Pos 2860774.0, False Neg 172385.0, Dice score 0.43
# 3 Class, True Pos 97811.0, False Pos 634206.0, False Neg 465965.0, Dice score 0.15
# 4 Class, True Pos 226.0, False Pos 520.0, False Neg 4942418.0, Dice score 0.00
# 5 Class, True Pos 786170.0, False Pos 966489.0, False Neg 2707629.0, Dice score 0.30
# 6 Class, True Pos 0.0, False Pos 0.0, False Neg 94186.0, Dice score 0.00
# 7 Class, True Pos 0.0, False Pos 0.0, False Neg 139522.0, Dice score 0.00
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 0.0, False Pos 0.0, False Neg 114383.0, Dice score 0.00
# 10 Class, True Pos 0.0, False Pos 0.0, False Neg 2725129.0, Dice score 0.00
# 11 Class, True Pos 0.0, False Pos 0.0, False Neg 175961.0, Dice score 0.00
# ----------
# Dice Score: 0.1733
# ----------
#
# EPOCH 2 of 50
#
# Training Loss: 0.6973
# 0 Class, True Pos 44819176.0, False Pos 25724300.0, False Neg 8324931.0, Dice score 0.72
# 1 Class, True Pos 9576110.0, False Pos 1860461.0, False Neg 1344738.0, Dice score 0.86
# 2 Class, True Pos 3663317.0, False Pos 1725664.0, False Neg 1689384.0, Dice score 0.68
# 3 Class, True Pos 1702449.0, False Pos 1141638.0, False Neg 774911.0, Dice score 0.64
# 4 Class, True Pos 1447507.0, False Pos 3764254.0, False Neg 18612356.0, Dice score 0.11
# 5 Class, True Pos 8733116.0, False Pos 7338532.0, False Neg 4962982.0, Dice score 0.59
# 6 Class, True Pos 350.0, False Pos 3634.0, False Neg 418269.0, Dice score 0.00
# 7 Class, True Pos 147126.0, False Pos 289823.0, False Neg 466176.0, Dice score 0.28
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 0.0, False Pos 0.0, False Neg 487516.0, Dice score 0.00
# 10 Class, True Pos 2560086.0, False Pos 2729984.0, False Neg 6931382.0, Dice score 0.35
# 11 Class, True Pos 0.0, False Pos 0.0, False Neg 561446.0, Dice score 0.00
# Vaildation Loss: 0.6573
# 0 Class, True Pos 9784593.0, False Pos 4768742.0, False Neg 3340910.0, Dice score 0.71
# 1 Class, True Pos 2122849.0, False Pos 406952.0, False Neg 414055.0, Dice score 0.84
# 2 Class, True Pos 565471.0, False Pos 86959.0, False Neg 767663.0, Dice score 0.57
# 3 Class, True Pos 422945.0, False Pos 382214.0, False Neg 140831.0, Dice score 0.62
# 4 Class, True Pos 1282781.0, False Pos 1937931.0, False Neg 3659863.0, Dice score 0.31
# 5 Class, True Pos 1961295.0, False Pos 1344323.0, False Neg 1532504.0, Dice score 0.58
# 6 Class, True Pos 4.0, False Pos 64.0, False Neg 94182.0, Dice score 0.00
# 7 Class, True Pos 61407.0, False Pos 56312.0, False Neg 78115.0, Dice score 0.48
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 0.0, False Pos 0.0, False Neg 114383.0, Dice score 0.00
# 10 Class, True Pos 2034189.0, False Pos 2026409.0, False Neg 690940.0, Dice score 0.60
# 11 Class, True Pos 0.0, False Pos 0.0, False Neg 175961.0, Dice score 0.00
# ----------
# Dice Score: 0.3917
# ----------
#
# EPOCH 3 of 50
#
# Training Loss: 0.5223
# 0 Class, True Pos 43637512.0, False Pos 11586688.0, False Neg 9506582.0, Dice score 0.81
# 1 Class, True Pos 9828109.0, False Pos 1629607.0, False Neg 1092739.0, Dice score 0.88
# 2 Class, True Pos 3839150.0, False Pos 1344737.0, False Neg 1513551.0, Dice score 0.73
# 3 Class, True Pos 1814164.0, False Pos 737905.0, False Neg 663196.0, Dice score 0.72
# 4 Class, True Pos 12769969.0, False Pos 7443278.0, False Neg 7289896.0, Dice score 0.63
# 5 Class, True Pos 9703116.0, False Pos 3351168.0, False Neg 3992982.0, Dice score 0.73
# 6 Class, True Pos 159789.0, False Pos 190614.0, False Neg 258830.0, Dice score 0.42
# 7 Class, True Pos 397299.0, False Pos 191194.0, False Neg 216003.0, Dice score 0.66
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 1.0, False Pos 13.0, False Neg 487515.0, Dice score 0.00
# 10 Class, True Pos 6922412.0, False Pos 1680784.0, False Neg 2569056.0, Dice score 0.77
# 11 Class, True Pos 0.0, False Pos 0.0, False Neg 561446.0, Dice score 0.00
# Vaildation Loss: 0.5212
# 0 Class, True Pos 7673153.0, False Pos 1082506.0, False Neg 5452350.0, Dice score 0.70
# 1 Class, True Pos 2262757.0, False Pos 321686.0, False Neg 274147.0, Dice score 0.88
# 2 Class, True Pos 957825.0, False Pos 268257.0, False Neg 375309.0, Dice score 0.75
# 3 Class, True Pos 379421.0, False Pos 72272.0, False Neg 184355.0, Dice score 0.75
# 4 Class, True Pos 4109759.0, False Pos 4931399.0, False Neg 832885.0, Dice score 0.59
# 5 Class, True Pos 3014496.0, False Pos 1355389.0, False Neg 479303.0, Dice score 0.77
# 6 Class, True Pos 36192.0, False Pos 27674.0, False Neg 57994.0, Dice score 0.46
# 7 Class, True Pos 122063.0, False Pos 186174.0, False Neg 17459.0, Dice score 0.55
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 0.0, False Pos 0.0, False Neg 114383.0, Dice score 0.00
# 10 Class, True Pos 2077146.0, False Pos 367271.0, False Neg 647983.0, Dice score 0.80
# 11 Class, True Pos 0.0, False Pos 0.0, False Neg 175961.0, Dice score 0.00
# ----------
# Dice Score: 0.5202
# ----------
#
# EPOCH 4 of 50
#
# Training Loss: 0.4452
# 0 Class, True Pos 46662308.0, False Pos 9206452.0, False Neg 6481794.0, Dice score 0.86
# 1 Class, True Pos 9822927.0, False Pos 1319413.0, False Neg 1097921.0, Dice score 0.89
# 2 Class, True Pos 4034943.0, False Pos 1133214.0, False Neg 1317758.0, Dice score 0.77
# 3 Class, True Pos 1906325.0, False Pos 570654.0, False Neg 571035.0, Dice score 0.77
# 4 Class, True Pos 15084243.0, False Pos 4308521.0, False Neg 4975622.0, Dice score 0.76
# 5 Class, True Pos 10600982.0, False Pos 2381261.0, False Neg 3095116.0, Dice score 0.79
# 6 Class, True Pos 234617.0, False Pos 182066.0, False Neg 184002.0, Dice score 0.56
# 7 Class, True Pos 450107.0, False Pos 105554.0, False Neg 163195.0, Dice score 0.77
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 102633.0, False Pos 419171.0, False Neg 384883.0, Dice score 0.20
# 10 Class, True Pos 7561508.0, False Pos 1140615.0, False Neg 1929960.0, Dice score 0.83
# 11 Class, True Pos 0.0, False Pos 3.0, False Neg 561446.0, Dice score 0.00
# Vaildation Loss: 0.4323
# 0 Class, True Pos 11426869.0, False Pos 2020992.0, False Neg 1698634.0, Dice score 0.86
# 1 Class, True Pos 2206232.0, False Pos 238445.0, False Neg 330672.0, Dice score 0.89
# 2 Class, True Pos 1031891.0, False Pos 417703.0, False Neg 301243.0, Dice score 0.74
# 3 Class, True Pos 413183.0, False Pos 95197.0, False Neg 150593.0, Dice score 0.77
# 4 Class, True Pos 3853584.0, False Pos 804080.0, False Neg 1089060.0, Dice score 0.80
# 5 Class, True Pos 2809116.0, False Pos 600859.0, False Neg 684683.0, Dice score 0.81
# 6 Class, True Pos 45020.0, False Pos 26907.0, False Neg 49166.0, Dice score 0.54
# 7 Class, True Pos 103201.0, False Pos 14894.0, False Neg 36321.0, Dice score 0.80
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 67228.0, False Pos 82783.0, False Neg 47155.0, Dice score 0.51
# 10 Class, True Pos 2449814.0, False Pos 537423.0, False Neg 275315.0, Dice score 0.86
# 11 Class, True Pos 0.0, False Pos 19.0, False Neg 175961.0, Dice score 0.00
# ----------
# Dice Score: 0.6320
# ----------
#
# EPOCH 5 of 50
#
# Training Loss: 0.4043
# 0 Class, True Pos 47724056.0, False Pos 8344118.0, False Neg 5420057.0, Dice score 0.87
# 1 Class, True Pos 9674371.0, False Pos 1149247.0, False Neg 1246477.0, Dice score 0.89
# 2 Class, True Pos 4056095.0, False Pos 1223751.0, False Neg 1296606.0, Dice score 0.76
# 3 Class, True Pos 1900761.0, False Pos 575549.0, False Neg 576599.0, Dice score 0.77
# 4 Class, True Pos 15950501.0, False Pos 3482193.0, False Neg 4109364.0, Dice score 0.81
# 5 Class, True Pos 11045914.0, False Pos 1993024.0, False Neg 2650184.0, Dice score 0.83
# 6 Class, True Pos 243945.0, False Pos 156409.0, False Neg 174674.0, Dice score 0.60
# 7 Class, True Pos 472284.0, False Pos 87088.0, False Neg 141018.0, Dice score 0.81
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 289341.0, False Pos 235296.0, False Neg 198175.0, Dice score 0.57
# 10 Class, True Pos 7567023.0, False Pos 842744.0, False Neg 1924445.0, Dice score 0.85
# 11 Class, True Pos 18548.0, False Pos 195270.0, False Neg 542898.0, Dice score 0.05
# Vaildation Loss: 0.4087
# 0 Class, True Pos 12083658.0, False Pos 2414746.0, False Neg 1041845.0, Dice score 0.87
# 1 Class, True Pos 2287752.0, False Pos 337523.0, False Neg 249152.0, Dice score 0.89
# 2 Class, True Pos 910586.0, False Pos 181356.0, False Neg 422548.0, Dice score 0.75
# 3 Class, True Pos 466832.0, False Pos 210209.0, False Neg 96944.0, Dice score 0.75
# 4 Class, True Pos 3538059.0, False Pos 339319.0, False Neg 1404585.0, Dice score 0.80
# 5 Class, True Pos 3050574.0, False Pos 681635.0, False Neg 443225.0, Dice score 0.84
# 6 Class, True Pos 45585.0, False Pos 18747.0, False Neg 48601.0, Dice score 0.58
# 7 Class, True Pos 98299.0, False Pos 13998.0, False Neg 41223.0, Dice score 0.78
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 59023.0, False Pos 24700.0, False Neg 55360.0, Dice score 0.60
# 10 Class, True Pos 2239879.0, False Pos 172792.0, False Neg 485250.0, Dice score 0.87
# 11 Class, True Pos 8614.0, False Pos 61554.0, False Neg 167347.0, Dice score 0.07
# ----------
# Dice Score: 0.6504
# ----------
#
# EPOCH 6 of 50
#
# Training Loss: 0.3636
# 0 Class, True Pos 48788464.0, False Pos 7254921.0, False Neg 4355637.0, Dice score 0.89
# 1 Class, True Pos 9830398.0, False Pos 885333.0, False Neg 1090450.0, Dice score 0.91
# 2 Class, True Pos 4100397.0, False Pos 985439.0, False Neg 1252304.0, Dice score 0.79
# 3 Class, True Pos 1952458.0, False Pos 435311.0, False Neg 524902.0, Dice score 0.80
# 4 Class, True Pos 16688143.0, False Pos 2527019.0, False Neg 3371722.0, Dice score 0.85
# 5 Class, True Pos 11267129.0, False Pos 1761433.0, False Neg 2428969.0, Dice score 0.84
# 6 Class, True Pos 258573.0, False Pos 139740.0, False Neg 160046.0, Dice score 0.63
# 7 Class, True Pos 491076.0, False Pos 76222.0, False Neg 122226.0, Dice score 0.83
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 318561.0, False Pos 123557.0, False Neg 168955.0, Dice score 0.69
# 10 Class, True Pos 7902579.0, False Pos 738280.0, False Neg 1588889.0, Dice score 0.87
# 11 Class, True Pos 163042.0, False Pos 539441.0, False Neg 398404.0, Dice score 0.26
# Vaildation Loss: 0.3691
# 0 Class, True Pos 12422872.0, False Pos 2060623.0, False Neg 702631.0, Dice score 0.90
# 1 Class, True Pos 2221135.0, False Pos 211792.0, False Neg 315769.0, Dice score 0.89
# 2 Class, True Pos 1011690.0, False Pos 189373.0, False Neg 321444.0, Dice score 0.80
# 3 Class, True Pos 450236.0, False Pos 98868.0, False Neg 113540.0, Dice score 0.81
# 4 Class, True Pos 3928554.0, False Pos 285338.0, False Neg 1014090.0, Dice score 0.86
# 5 Class, True Pos 2969602.0, False Pos 289352.0, False Neg 524197.0, Dice score 0.88
# 6 Class, True Pos 52412.0, False Pos 22722.0, False Neg 41774.0, Dice score 0.62
# 7 Class, True Pos 108193.0, False Pos 10389.0, False Neg 31329.0, Dice score 0.84
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 76406.0, False Pos 36366.0, False Neg 37977.0, Dice score 0.67
# 10 Class, True Pos 2328786.0, False Pos 119915.0, False Neg 396343.0, Dice score 0.90
# 11 Class, True Pos 78748.0, False Pos 272068.0, False Neg 97213.0, Dice score 0.30
# ----------
# Dice Score: 0.7057
# ----------
#
# EPOCH 7 of 50
#
# Training Loss: 0.3346
# 0 Class, True Pos 49427200.0, False Pos 6133335.0, False Neg 3716906.0, Dice score 0.91
# 1 Class, True Pos 10107423.0, False Pos 798977.0, False Neg 813425.0, Dice score 0.93
# 2 Class, True Pos 4290774.0, False Pos 912199.0, False Neg 1061927.0, Dice score 0.81
# 3 Class, True Pos 1991301.0, False Pos 408915.0, False Neg 486059.0, Dice score 0.82
# 4 Class, True Pos 17268796.0, False Pos 2269946.0, False Neg 2791068.0, Dice score 0.87
# 5 Class, True Pos 11534909.0, False Pos 1392866.0, False Neg 2161189.0, Dice score 0.87
# 6 Class, True Pos 270157.0, False Pos 126122.0, False Neg 148462.0, Dice score 0.66
# 7 Class, True Pos 506780.0, False Pos 63725.0, False Neg 106522.0, Dice score 0.86
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 370393.0, False Pos 89787.0, False Neg 117123.0, Dice score 0.78
# 10 Class, True Pos 8131537.0, False Pos 558667.0, False Neg 1359931.0, Dice score 0.89
# 11 Class, True Pos 256072.0, False Pos 317639.0, False Neg 305374.0, Dice score 0.45
# Vaildation Loss: 0.3383
# 0 Class, True Pos 12234601.0, False Pos 1608879.0, False Neg 890902.0, Dice score 0.91
# 1 Class, True Pos 2294678.0, False Pos 186114.0, False Neg 242226.0, Dice score 0.91
# 2 Class, True Pos 1093081.0, False Pos 244420.0, False Neg 240053.0, Dice score 0.82
# 3 Class, True Pos 427437.0, False Pos 76000.0, False Neg 136339.0, Dice score 0.80
# 4 Class, True Pos 4183278.0, False Pos 359107.0, False Neg 759366.0, Dice score 0.88
# 5 Class, True Pos 2923792.0, False Pos 190753.0, False Neg 570007.0, Dice score 0.88
# 6 Class, True Pos 56450.0, False Pos 30639.0, False Neg 37736.0, Dice score 0.62
# 7 Class, True Pos 123873.0, False Pos 30740.0, False Neg 15649.0, Dice score 0.84
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 74335.0, False Pos 15620.0, False Neg 40048.0, Dice score 0.73
# 10 Class, True Pos 2560084.0, False Pos 356770.0, False Neg 165045.0, Dice score 0.91
# 11 Class, True Pos 111058.0, False Pos 63731.0, False Neg 64903.0, Dice score 0.63
# ----------
# Dice Score: 0.7452
# ----------
#
# EPOCH 8 of 50
#
# Training Loss: 0.3187
# 0 Class, True Pos 49668392.0, False Pos 5782293.0, False Neg 3475721.0, Dice score 0.91
# 1 Class, True Pos 10151565.0, False Pos 757118.0, False Neg 769283.0, Dice score 0.93
# 2 Class, True Pos 4383656.0, False Pos 890731.0, False Neg 969045.0, Dice score 0.82
# 3 Class, True Pos 2022831.0, False Pos 369923.0, False Neg 454529.0, Dice score 0.83
# 4 Class, True Pos 17201638.0, False Pos 1847749.0, False Neg 2858226.0, Dice score 0.88
# 5 Class, True Pos 11736133.0, False Pos 1458978.0, False Neg 1959965.0, Dice score 0.87
# 6 Class, True Pos 270623.0, False Pos 121001.0, False Neg 147996.0, Dice score 0.67
# 7 Class, True Pos 505522.0, False Pos 72273.0, False Neg 107780.0, Dice score 0.85
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 383324.0, False Pos 73060.0, False Neg 104192.0, Dice score 0.81
# 10 Class, True Pos 8402545.0, False Pos 531675.0, False Neg 1088923.0, Dice score 0.91
# 11 Class, True Pos 344809.0, False Pos 251688.0, False Neg 216637.0, Dice score 0.60
# Vaildation Loss: 0.3354
# 0 Class, True Pos 12370473.0, False Pos 1353077.0, False Neg 755030.0, Dice score 0.92
# 1 Class, True Pos 2329613.0, False Pos 213879.0, False Neg 207291.0, Dice score 0.92
# 2 Class, True Pos 1038907.0, False Pos 168498.0, False Neg 294227.0, Dice score 0.82
# 3 Class, True Pos 475082.0, False Pos 120888.0, False Neg 88694.0, Dice score 0.82
# 4 Class, True Pos 4385779.0, False Pos 336648.0, False Neg 556865.0, Dice score 0.91
# 5 Class, True Pos 3044534.0, False Pos 248682.0, False Neg 449265.0, Dice score 0.90
# 6 Class, True Pos 55551.0, False Pos 23202.0, False Neg 38635.0, Dice score 0.64
# 7 Class, True Pos 118230.0, False Pos 14531.0, False Neg 21292.0, Dice score 0.87
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 78995.0, False Pos 9603.0, False Neg 35388.0, Dice score 0.78
# 10 Class, True Pos 2518964.0, False Pos 270450.0, False Neg 206165.0, Dice score 0.91
# 11 Class, True Pos 60500.0, False Pos 9354.0, False Neg 115461.0, Dice score 0.49
# ----------
# Dice Score: 0.7480
# ----------
#
# EPOCH 9 of 50
#
# Training Loss: 0.3065
# 0 Class, True Pos 49925356.0, False Pos 5267091.0, False Neg 3218738.0, Dice score 0.92
# 1 Class, True Pos 10179977.0, False Pos 733540.0, False Neg 740871.0, Dice score 0.93
# 2 Class, True Pos 4463844.0, False Pos 854129.0, False Neg 888857.0, Dice score 0.84
# 3 Class, True Pos 2062220.0, False Pos 373474.0, False Neg 415140.0, Dice score 0.84
# 4 Class, True Pos 17620600.0, False Pos 1636979.0, False Neg 2439267.0, Dice score 0.90
# 5 Class, True Pos 11848461.0, False Pos 1262924.0, False Neg 1847637.0, Dice score 0.88
# 6 Class, True Pos 281809.0, False Pos 120293.0, False Neg 136810.0, Dice score 0.69
# 7 Class, True Pos 519826.0, False Pos 60464.0, False Neg 93476.0, Dice score 0.87
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 372563.0, False Pos 52404.0, False Neg 114953.0, Dice score 0.82
# 10 Class, True Pos 8323446.0, False Pos 624355.0, False Neg 1168022.0, Dice score 0.90
# 11 Class, True Pos 379161.0, False Pos 264595.0, False Neg 182285.0, Dice score 0.63
# Vaildation Loss: 0.3533
# 0 Class, True Pos 12086583.0, False Pos 1924263.0, False Neg 1038920.0, Dice score 0.89
# 1 Class, True Pos 2363420.0, False Pos 345709.0, False Neg 173484.0, Dice score 0.90
# 2 Class, True Pos 1162636.0, False Pos 479415.0, False Neg 170498.0, Dice score 0.78
# 3 Class, True Pos 483205.0, False Pos 153753.0, False Neg 80571.0, Dice score 0.80
# 4 Class, True Pos 4358397.0, False Pos 659552.0, False Neg 584247.0, Dice score 0.88
# 5 Class, True Pos 2882982.0, False Pos 166603.0, False Neg 610817.0, Dice score 0.88
# 6 Class, True Pos 56825.0, False Pos 28530.0, False Neg 37361.0, Dice score 0.63
# 7 Class, True Pos 116876.0, False Pos 13084.0, False Neg 22646.0, Dice score 0.87
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 76590.0, False Pos 65785.0, False Neg 37793.0, Dice score 0.60
# 10 Class, True Pos 1632014.0, False Pos 27766.0, False Neg 1093115.0, Dice score 0.74
# 11 Class, True Pos 103077.0, False Pos 58375.0, False Neg 72884.0, Dice score 0.61
# ----------
# ----------
#
# EPOCH 10 of 50
#
# Training Loss: 0.2940
# 0 Class, True Pos 50330968.0, False Pos 5091559.0, False Neg 2813114.0, Dice score 0.93
# 1 Class, True Pos 10242983.0, False Pos 696283.0, False Neg 677865.0, Dice score 0.94
# 2 Class, True Pos 4466160.0, False Pos 817610.0, False Neg 886541.0, Dice score 0.84
# 3 Class, True Pos 2074911.0, False Pos 318518.0, False Neg 402449.0, Dice score 0.85
# 4 Class, True Pos 17852304.0, False Pos 1465510.0, False Neg 2207563.0, Dice score 0.91
# 5 Class, True Pos 12100145.0, False Pos 968290.0, False Neg 1595953.0, Dice score 0.90
# 6 Class, True Pos 283419.0, False Pos 117064.0, False Neg 135200.0, Dice score 0.69
# 7 Class, True Pos 520534.0, False Pos 58978.0, False Neg 92768.0, Dice score 0.87
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 411775.0, False Pos 68708.0, False Neg 75741.0, Dice score 0.85
# 10 Class, True Pos 8368067.0, False Pos 427341.0, False Neg 1123401.0, Dice score 0.92
# 11 Class, True Pos 425079.0, False Pos 121293.0, False Neg 136367.0, Dice score 0.77
# Vaildation Loss: 0.3370
# 0 Class, True Pos 12457738.0, False Pos 1341967.0, False Neg 667765.0, Dice score 0.93
# 1 Class, True Pos 2368941.0, False Pos 229608.0, False Neg 167963.0, Dice score 0.92
# 2 Class, True Pos 1135488.0, False Pos 268122.0, False Neg 197646.0, Dice score 0.83
# 3 Class, True Pos 441869.0, False Pos 65792.0, False Neg 121907.0, Dice score 0.82
# 4 Class, True Pos 4462022.0, False Pos 284066.0, False Neg 480622.0, Dice score 0.92
# 5 Class, True Pos 3028397.0, False Pos 158764.0, False Neg 465402.0, Dice score 0.91
# 6 Class, True Pos 75340.0, False Pos 153495.0, False Neg 18846.0, Dice score 0.47
# 7 Class, True Pos 120429.0, False Pos 16797.0, False Neg 19093.0, Dice score 0.87
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 81126.0, False Pos 16881.0, False Neg 33257.0, Dice score 0.76
# 10 Class, True Pos 2360976.0, False Pos 59347.0, False Neg 364153.0, Dice score 0.92
# 11 Class, True Pos 95049.0, False Pos 23226.0, False Neg 80912.0, Dice score 0.65
# ----------
# Dice Score: 0.7496
# ----------
#
# EPOCH 11 of 50
#
# Training Loss: 0.2819
# 0 Class, True Pos 50512148.0, False Pos 4369845.0, False Neg 2631945.0, Dice score 0.94
# 1 Class, True Pos 10320821.0, False Pos 657558.0, False Neg 600027.0, Dice score 0.94
# 2 Class, True Pos 4567544.0, False Pos 779916.0, False Neg 785157.0, Dice score 0.85
# 3 Class, True Pos 2088237.0, False Pos 304926.0, False Neg 389123.0, Dice score 0.86
# 4 Class, True Pos 18306920.0, False Pos 1268100.0, False Neg 1752948.0, Dice score 0.92
# 5 Class, True Pos 12300278.0, False Pos 903860.0, False Neg 1395820.0, Dice score 0.91
# 6 Class, True Pos 283738.0, False Pos 108863.0, False Neg 134881.0, Dice score 0.70
# 7 Class, True Pos 523191.0, False Pos 53638.0, False Neg 90111.0, Dice score 0.88
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 406278.0, False Pos 48756.0, False Neg 81238.0, Dice score 0.86
# 10 Class, True Pos 8491165.0, False Pos 400861.0, False Neg 1000303.0, Dice score 0.92
# 11 Class, True Pos 443812.0, False Pos 87056.0, False Neg 117634.0, Dice score 0.81
# Vaildation Loss: 0.3112
# 0 Class, True Pos 12526741.0, False Pos 1115308.0, False Neg 598762.0, Dice score 0.94
# 1 Class, True Pos 2365683.0, False Pos 151065.0, False Neg 171221.0, Dice score 0.94
# 2 Class, True Pos 1087566.0, False Pos 188750.0, False Neg 245568.0, Dice score 0.83
# 3 Class, True Pos 485363.0, False Pos 113154.0, False Neg 78413.0, Dice score 0.84
# 4 Class, True Pos 4535515.0, False Pos 304600.0, False Neg 407129.0, Dice score 0.93
# 5 Class, True Pos 3111333.0, False Pos 189063.0, False Neg 382466.0, Dice score 0.92
# 6 Class, True Pos 61982.0, False Pos 30608.0, False Neg 32204.0, Dice score 0.66
# 7 Class, True Pos 117471.0, False Pos 10721.0, False Neg 22051.0, Dice score 0.88
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 77722.0, False Pos 10863.0, False Neg 36661.0, Dice score 0.77
# 10 Class, True Pos 2496755.0, False Pos 119193.0, False Neg 228374.0, Dice score 0.93
# 11 Class, True Pos 131965.0, False Pos 14019.0, False Neg 43996.0, Dice score 0.82
# ----------
# Dice Score: 0.7872
# ----------
#
# EPOCH 12 of 50
#
# Training Loss: 0.2774
# 0 Class, True Pos 50494636.0, False Pos 3853997.0, False Neg 2649474.0, Dice score 0.94
# 1 Class, True Pos 10355799.0, False Pos 618211.0, False Neg 565049.0, Dice score 0.95
# 2 Class, True Pos 4594303.0, False Pos 748984.0, False Neg 758398.0, Dice score 0.86
# 3 Class, True Pos 2101536.0, False Pos 296678.0, False Neg 375824.0, Dice score 0.86
# 4 Class, True Pos 18425336.0, False Pos 1232855.0, False Neg 1634525.0, Dice score 0.93
# 5 Class, True Pos 12462770.0, False Pos 880978.0, False Neg 1233328.0, Dice score 0.92
# 6 Class, True Pos 292738.0, False Pos 108151.0, False Neg 125881.0, Dice score 0.71
# 7 Class, True Pos 528626.0, False Pos 51962.0, False Neg 84676.0, Dice score 0.89
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 421838.0, False Pos 47110.0, False Neg 65678.0, Dice score 0.88
# 10 Class, True Pos 8698945.0, False Pos 427660.0, False Neg 792523.0, Dice score 0.93
# 11 Class, True Pos 481327.0, False Pos 103081.0, False Neg 80119.0, Dice score 0.84
# Vaildation Loss: 0.3139
# 0 Class, True Pos 12454731.0, False Pos 1072842.0, False Neg 670772.0, Dice score 0.93
# 1 Class, True Pos 2341012.0, False Pos 136181.0, False Neg 195892.0, Dice score 0.93
# 2 Class, True Pos 1090604.0, False Pos 179571.0, False Neg 242530.0, Dice score 0.84
# 3 Class, True Pos 500911.0, False Pos 178963.0, False Neg 62865.0, Dice score 0.81
# 4 Class, True Pos 4597334.0, False Pos 433855.0, False Neg 345310.0, Dice score 0.92
# 5 Class, True Pos 3054916.0, False Pos 135585.0, False Neg 438883.0, Dice score 0.91
# 6 Class, True Pos 58631.0, False Pos 25650.0, False Neg 35555.0, Dice score 0.66
# 7 Class, True Pos 122804.0, False Pos 18219.0, False Neg 16718.0, Dice score 0.88
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 86996.0, False Pos 14048.0, False Neg 27387.0, Dice score 0.81
# 10 Class, True Pos 2495034.0, False Pos 94098.0, False Neg 230095.0, Dice score 0.94
# 11 Class, True Pos 138455.0, False Pos 15000.0, False Neg 37506.0, Dice score 0.84
# ----------
# Dice Score: 0.7890
# ----------
#
# EPOCH 13 of 50
#
# Training Loss: 0.2625
# 0 Class, True Pos 50837696.0, False Pos 3444244.0, False Neg 2306410.0, Dice score 0.95
# 1 Class, True Pos 10424294.0, False Pos 576830.0, False Neg 496554.0, Dice score 0.95
# 2 Class, True Pos 4629361.0, False Pos 702856.0, False Neg 723340.0, Dice score 0.87
# 3 Class, True Pos 2127178.0, False Pos 291234.0, False Neg 350182.0, Dice score 0.87
# 4 Class, True Pos 18485042.0, False Pos 1051237.0, False Neg 1574821.0, Dice score 0.93
# 5 Class, True Pos 12651209.0, False Pos 830012.0, False Neg 1044889.0, Dice score 0.93
# 6 Class, True Pos 291941.0, False Pos 98966.0, False Neg 126678.0, Dice score 0.72
# 7 Class, True Pos 533882.0, False Pos 51262.0, False Neg 79420.0, Dice score 0.89
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 415624.0, False Pos 43080.0, False Neg 71892.0, Dice score 0.88
# 10 Class, True Pos 8847485.0, False Pos 321900.0, False Neg 643983.0, Dice score 0.95
# 11 Class, True Pos 504190.0, False Pos 67996.0, False Neg 57256.0, Dice score 0.89
# Vaildation Loss: 0.3036
# 0 Class, True Pos 12596462.0, False Pos 899818.0, False Neg 529041.0, Dice score 0.95
# 1 Class, True Pos 2391836.0, False Pos 148752.0, False Neg 145068.0, Dice score 0.94
# 2 Class, True Pos 1105311.0, False Pos 143820.0, False Neg 227823.0, Dice score 0.86
# 3 Class, True Pos 486186.0, False Pos 82103.0, False Neg 77590.0, Dice score 0.86
# 4 Class, True Pos 4570807.0, False Pos 226065.0, False Neg 371837.0, Dice score 0.94
# 5 Class, True Pos 3245211.0, False Pos 174608.0, False Neg 248588.0, Dice score 0.94
# 6 Class, True Pos 65663.0, False Pos 38317.0, False Neg 28523.0, Dice score 0.66
# 7 Class, True Pos 87884.0, False Pos 2669.0, False Neg 51638.0, Dice score 0.76
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 83363.0, False Pos 7739.0, False Neg 31020.0, Dice score 0.81
# 10 Class, True Pos 2590273.0, False Pos 123289.0, False Neg 134856.0, Dice score 0.95
# 11 Class, True Pos 147814.0, False Pos 27450.0, False Neg 28147.0, Dice score 0.84
# ----------
# Dice Score: 0.7928
# ----------
#
# EPOCH 14 of 50
#
# Training Loss: 0.2620
# 0 Class, True Pos 50910832.0, False Pos 3248193.0, False Neg 2233286.0, Dice score 0.95
# 1 Class, True Pos 10438801.0, False Pos 527536.0, False Neg 482047.0, Dice score 0.95
# 2 Class, True Pos 4671774.0, False Pos 675624.0, False Neg 680927.0, Dice score 0.87
# 3 Class, True Pos 2140314.0, False Pos 268735.0, False Neg 337046.0, Dice score 0.88
# 4 Class, True Pos 18756004.0, False Pos 1023712.0, False Neg 1303864.0, Dice score 0.94
# 5 Class, True Pos 12672592.0, False Pos 731127.0, False Neg 1023506.0, Dice score 0.94
# 6 Class, True Pos 301105.0, False Pos 104166.0, False Neg 117514.0, Dice score 0.73
# 7 Class, True Pos 540452.0, False Pos 49103.0, False Neg 72850.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 429833.0, False Pos 36180.0, False Neg 57683.0, Dice score 0.90
# 10 Class, True Pos 8803370.0, False Pos 339666.0, False Neg 688098.0, Dice score 0.94
# 11 Class, True Pos 509988.0, False Pos 48429.0, False Neg 51458.0, Dice score 0.91
# Vaildation Loss: 0.2866
# 0 Class, True Pos 12484497.0, False Pos 733686.0, False Neg 641006.0, Dice score 0.95
# 1 Class, True Pos 2354422.0, False Pos 113888.0, False Neg 182482.0, Dice score 0.94
# 2 Class, True Pos 1151170.0, False Pos 194852.0, False Neg 181964.0, Dice score 0.86
# 3 Class, True Pos 475127.0, False Pos 70755.0, False Neg 88649.0, Dice score 0.86
# 4 Class, True Pos 4665183.0, False Pos 304732.0, False Neg 277461.0, Dice score 0.94
# 5 Class, True Pos 3274419.0, False Pos 216944.0, False Neg 219380.0, Dice score 0.94
# 6 Class, True Pos 54194.0, False Pos 14656.0, False Neg 39992.0, Dice score 0.66
# 7 Class, True Pos 116557.0, False Pos 11549.0, False Neg 22965.0, Dice score 0.87
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 85818.0, False Pos 7239.0, False Neg 28565.0, Dice score 0.83
# 10 Class, True Pos 2608379.0, False Pos 149687.0, False Neg 116750.0, Dice score 0.95
# 11 Class, True Pos 140057.0, False Pos 17629.0, False Neg 35904.0, Dice score 0.84
# ----------
# Dice Score: 0.8031
# ----------
#
# EPOCH 15 of 50
#
# Training Loss: 0.2542
# 0 Class, True Pos 50903596.0, False Pos 2895586.0, False Neg 2240509.0, Dice score 0.95
# 1 Class, True Pos 10468061.0, False Pos 527866.0, False Neg 452787.0, Dice score 0.96
# 2 Class, True Pos 4692488.0, False Pos 695185.0, False Neg 660213.0, Dice score 0.87
# 3 Class, True Pos 2117615.0, False Pos 253493.0, False Neg 359745.0, Dice score 0.87
# 4 Class, True Pos 18811448.0, False Pos 1053042.0, False Neg 1248416.0, Dice score 0.94
# 5 Class, True Pos 12706265.0, False Pos 717861.0, False Neg 989833.0, Dice score 0.94
# 6 Class, True Pos 302551.0, False Pos 99145.0, False Neg 116068.0, Dice score 0.74
# 7 Class, True Pos 542298.0, False Pos 48932.0, False Neg 71004.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 437660.0, False Pos 33795.0, False Neg 49856.0, Dice score 0.91
# 10 Class, True Pos 9019089.0, False Pos 348925.0, False Neg 472379.0, Dice score 0.96
# 11 Class, True Pos 508498.0, False Pos 44120.0, False Neg 52948.0, Dice score 0.91
# Vaildation Loss: 0.3109
# 0 Class, True Pos 12263540.0, False Pos 847500.0, False Neg 861963.0, Dice score 0.93
# 1 Class, True Pos 2379689.0, False Pos 149588.0, False Neg 157215.0, Dice score 0.94
# 2 Class, True Pos 1098083.0, False Pos 148302.0, False Neg 235051.0, Dice score 0.85
# 3 Class, True Pos 461598.0, False Pos 61848.0, False Neg 102178.0, Dice score 0.85
# 4 Class, True Pos 4719629.0, False Pos 698339.0, False Neg 223015.0, Dice score 0.91
# 5 Class, True Pos 3164603.0, False Pos 149894.0, False Neg 329196.0, Dice score 0.93
# 6 Class, True Pos 56112.0, False Pos 19862.0, False Neg 38074.0, Dice score 0.66
# 7 Class, True Pos 125907.0, False Pos 17861.0, False Neg 13615.0, Dice score 0.89
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 89132.0, False Pos 50067.0, False Neg 25251.0, Dice score 0.70
# 10 Class, True Pos 2499480.0, False Pos 88036.0, False Neg 225649.0, Dice score 0.94
# 11 Class, True Pos 139679.0, False Pos 16691.0, False Neg 36282.0, Dice score 0.84
# ----------
# ----------
#
# EPOCH 16 of 50
#
# Training Loss: 0.2614
# 0 Class, True Pos 50999120.0, False Pos 2934861.0, False Neg 2144970.0, Dice score 0.95
# 1 Class, True Pos 10464346.0, False Pos 550973.0, False Neg 456502.0, Dice score 0.95
# 2 Class, True Pos 4697162.0, False Pos 679879.0, False Neg 655539.0, Dice score 0.88
# 3 Class, True Pos 2138415.0, False Pos 261222.0, False Neg 338945.0, Dice score 0.88
# 4 Class, True Pos 18870936.0, False Pos 950426.0, False Neg 1188935.0, Dice score 0.95
# 5 Class, True Pos 12775666.0, False Pos 707829.0, False Neg 920432.0, Dice score 0.94
# 6 Class, True Pos 303353.0, False Pos 96525.0, False Neg 115266.0, Dice score 0.74
# 7 Class, True Pos 542101.0, False Pos 43844.0, False Neg 71201.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 431815.0, False Pos 51504.0, False Neg 55701.0, Dice score 0.89
# 10 Class, True Pos 8814207.0, False Pos 353988.0, False Neg 677261.0, Dice score 0.94
# 11 Class, True Pos 502269.0, False Pos 57070.0, False Neg 59177.0, Dice score 0.90
# Vaildation Loss: 0.2983
# 0 Class, True Pos 12508633.0, False Pos 783122.0, False Neg 616870.0, Dice score 0.95
# 1 Class, True Pos 2386647.0, False Pos 173923.0, False Neg 150257.0, Dice score 0.94
# 2 Class, True Pos 1138435.0, False Pos 161746.0, False Neg 194699.0, Dice score 0.86
# 3 Class, True Pos 466820.0, False Pos 66309.0, False Neg 96956.0, Dice score 0.85
# 4 Class, True Pos 4632287.0, False Pos 258845.0, False Neg 310357.0, Dice score 0.94
# 5 Class, True Pos 3259282.0, False Pos 198853.0, False Neg 234517.0, Dice score 0.94
# 6 Class, True Pos 58236.0, False Pos 19458.0, False Neg 35950.0, Dice score 0.68
# 7 Class, True Pos 126988.0, False Pos 18793.0, False Neg 12534.0, Dice score 0.89
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 75994.0, False Pos 7803.0, False Neg 38389.0, Dice score 0.77
# 10 Class, True Pos 2575043.0, False Pos 112989.0, False Neg 150086.0, Dice score 0.95
# 11 Class, True Pos 147860.0, False Pos 67374.0, False Neg 28101.0, Dice score 0.76
# ----------
# ----------
#
# EPOCH 17 of 50
#
# Training Loss: 0.2492
# 0 Class, True Pos 51027420.0, False Pos 2536312.0, False Neg 2116690.0, Dice score 0.96
# 1 Class, True Pos 10499095.0, False Pos 549302.0, False Neg 421753.0, Dice score 0.96
# 2 Class, True Pos 4743722.0, False Pos 637259.0, False Neg 608979.0, Dice score 0.88
# 3 Class, True Pos 2160790.0, False Pos 245327.0, False Neg 316570.0, Dice score 0.88
# 4 Class, True Pos 18988548.0, False Pos 974932.0, False Neg 1071320.0, Dice score 0.95
# 5 Class, True Pos 12861489.0, False Pos 678062.0, False Neg 834609.0, Dice score 0.94
# 6 Class, True Pos 306884.0, False Pos 96569.0, False Neg 111735.0, Dice score 0.75
# 7 Class, True Pos 544643.0, False Pos 43172.0, False Neg 68659.0, Dice score 0.91
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 419405.0, False Pos 34653.0, False Neg 68111.0, Dice score 0.89
# 10 Class, True Pos 9047535.0, False Pos 285674.0, False Neg 443933.0, Dice score 0.96
# 11 Class, True Pos 508229.0, False Pos 38506.0, False Neg 53217.0, Dice score 0.92
# Vaildation Loss: 0.2880
# 0 Class, True Pos 12498841.0, False Pos 612265.0, False Neg 626662.0, Dice score 0.95
# 1 Class, True Pos 2421714.0, False Pos 152526.0, False Neg 115190.0, Dice score 0.95
# 2 Class, True Pos 1198903.0, False Pos 231624.0, False Neg 134231.0, Dice score 0.87
# 3 Class, True Pos 455398.0, False Pos 47475.0, False Neg 108378.0, Dice score 0.85
# 4 Class, True Pos 4737538.0, False Pos 346184.0, False Neg 205106.0, Dice score 0.95
# 5 Class, True Pos 3233172.0, False Pos 154780.0, False Neg 260627.0, Dice score 0.94
# 6 Class, True Pos 63724.0, False Pos 24703.0, False Neg 30462.0, Dice score 0.70
# 7 Class, True Pos 124142.0, False Pos 14031.0, False Neg 15380.0, Dice score 0.89
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 88096.0, False Pos 13840.0, False Neg 26287.0, Dice score 0.81
# 10 Class, True Pos 2572181.0, False Pos 87509.0, False Neg 152948.0, Dice score 0.96
# 11 Class, True Pos 144240.0, False Pos 22554.0, False Neg 31721.0, Dice score 0.84
# ----------
# Dice Score: 0.8092
# ----------
#
# EPOCH 18 of 50
#
# Training Loss: 0.2542
# 0 Class, True Pos 51111272.0, False Pos 2395049.0, False Neg 2032834.0, Dice score 0.96
# 1 Class, True Pos 10532404.0, False Pos 493047.0, False Neg 388444.0, Dice score 0.96
# 2 Class, True Pos 4795688.0, False Pos 603381.0, False Neg 557013.0, Dice score 0.89
# 3 Class, True Pos 2182104.0, False Pos 229631.0, False Neg 295256.0, Dice score 0.89
# 4 Class, True Pos 19017492.0, False Pos 857576.0, False Neg 1042369.0, Dice score 0.95
# 5 Class, True Pos 12933457.0, False Pos 644810.0, False Neg 762641.0, Dice score 0.95
# 6 Class, True Pos 307864.0, False Pos 89618.0, False Neg 110755.0, Dice score 0.75
# 7 Class, True Pos 551388.0, False Pos 43569.0, False Neg 61914.0, Dice score 0.91
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 448310.0, False Pos 28169.0, False Neg 39206.0, Dice score 0.93
# 10 Class, True Pos 9075410.0, False Pos 326399.0, False Neg 416058.0, Dice score 0.96
# 11 Class, True Pos 528656.0, False Pos 32223.0, False Neg 32790.0, Dice score 0.94
# Vaildation Loss: 0.2774
# 0 Class, True Pos 12568090.0, False Pos 656749.0, False Neg 557413.0, Dice score 0.95
# 1 Class, True Pos 2431617.0, False Pos 148828.0, False Neg 105287.0, Dice score 0.95
# 2 Class, True Pos 1191892.0, False Pos 181521.0, False Neg 141242.0, Dice score 0.88
# 3 Class, True Pos 477727.0, False Pos 61547.0, False Neg 86049.0, Dice score 0.87
# 4 Class, True Pos 4644280.0, False Pos 199548.0, False Neg 298364.0, Dice score 0.95
# 5 Class, True Pos 3280181.0, False Pos 166033.0, False Neg 213618.0, Dice score 0.95
# 6 Class, True Pos 61988.0, False Pos 20884.0, False Neg 32198.0, Dice score 0.70
# 7 Class, True Pos 126231.0, False Pos 15488.0, False Neg 13291.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 87804.0, False Pos 7068.0, False Neg 26579.0, Dice score 0.84
# 10 Class, True Pos 2625864.0, False Pos 132378.0, False Neg 99265.0, Dice score 0.96
# 11 Class, True Pos 143846.0, False Pos 15876.0, False Neg 32115.0, Dice score 0.86
# ----------
# Dice Score: 0.8165
# ----------
#
# EPOCH 19 of 50
#
# Training Loss: 0.2483
# 0 Class, True Pos 51212352.0, False Pos 2410531.0, False Neg 1931742.0, Dice score 0.96
# 1 Class, True Pos 10543950.0, False Pos 461496.0, False Neg 376898.0, Dice score 0.96
# 2 Class, True Pos 4810122.0, False Pos 581286.0, False Neg 542579.0, Dice score 0.90
# 3 Class, True Pos 2192099.0, False Pos 222642.0, False Neg 285261.0, Dice score 0.90
# 4 Class, True Pos 19033878.0, False Pos 800063.0, False Neg 1025986.0, Dice score 0.95
# 5 Class, True Pos 12918309.0, False Pos 665493.0, False Neg 777789.0, Dice score 0.95
# 6 Class, True Pos 313477.0, False Pos 93913.0, False Neg 105142.0, Dice score 0.76
# 7 Class, True Pos 545997.0, False Pos 51113.0, False Neg 67305.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 453914.0, False Pos 26057.0, False Neg 33602.0, Dice score 0.94
# 10 Class, True Pos 9040451.0, False Pos 289297.0, False Neg 451017.0, Dice score 0.96
# 11 Class, True Pos 533706.0, False Pos 27362.0, False Neg 27740.0, Dice score 0.95
# Vaildation Loss: 0.2647
# 0 Class, True Pos 12580650.0, False Pos 601660.0, False Neg 544853.0, Dice score 0.96
# 1 Class, True Pos 2417853.0, False Pos 130957.0, False Neg 119051.0, Dice score 0.95
# 2 Class, True Pos 1192501.0, False Pos 183471.0, False Neg 140633.0, Dice score 0.88
# 3 Class, True Pos 484951.0, False Pos 69986.0, False Neg 78825.0, Dice score 0.87
# 4 Class, True Pos 4719118.0, False Pos 251744.0, False Neg 223526.0, Dice score 0.95
# 5 Class, True Pos 3270407.0, False Pos 149366.0, False Neg 223392.0, Dice score 0.95
# 6 Class, True Pos 66247.0, False Pos 28307.0, False Neg 27939.0, Dice score 0.70
# 7 Class, True Pos 125343.0, False Pos 16233.0, False Neg 14179.0, Dice score 0.89
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 84315.0, False Pos 3768.0, False Neg 30068.0, Dice score 0.83
# 10 Class, True Pos 2607272.0, False Pos 100497.0, False Neg 117857.0, Dice score 0.96
# 11 Class, True Pos 144359.0, False Pos 16435.0, False Neg 31602.0, Dice score 0.86
# ----------
# ----------
#
# EPOCH 20 of 50
#
# Training Loss: 0.2348
# 0 Class, True Pos 51306768.0, False Pos 2097877.0, False Neg 1837334.0, Dice score 0.96
# 1 Class, True Pos 10561536.0, False Pos 434935.0, False Neg 359312.0, Dice score 0.96
# 2 Class, True Pos 4864771.0, False Pos 562857.0, False Neg 487930.0, Dice score 0.90
# 3 Class, True Pos 2203321.0, False Pos 206328.0, False Neg 274039.0, Dice score 0.90
# 4 Class, True Pos 19169240.0, False Pos 780485.0, False Neg 890623.0, Dice score 0.96
# 5 Class, True Pos 13027964.0, False Pos 579859.0, False Neg 668134.0, Dice score 0.95
# 6 Class, True Pos 320087.0, False Pos 91469.0, False Neg 98532.0, Dice score 0.77
# 7 Class, True Pos 553229.0, False Pos 41953.0, False Neg 60073.0, Dice score 0.92
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 455918.0, False Pos 24625.0, False Neg 31598.0, Dice score 0.94
# 10 Class, True Pos 9128582.0, False Pos 253359.0, False Neg 362886.0, Dice score 0.97
# 11 Class, True Pos 536013.0, False Pos 26339.0, False Neg 25433.0, Dice score 0.95
# Vaildation Loss: 0.2664
# 0 Class, True Pos 12588143.0, False Pos 598527.0, False Neg 537360.0, Dice score 0.96
# 1 Class, True Pos 2421506.0, False Pos 116423.0, False Neg 115398.0, Dice score 0.95
# 2 Class, True Pos 1196647.0, False Pos 173107.0, False Neg 136487.0, Dice score 0.89
# 3 Class, True Pos 471601.0, False Pos 52484.0, False Neg 92175.0, Dice score 0.87
# 4 Class, True Pos 4703686.0, False Pos 227102.0, False Neg 238958.0, Dice score 0.95
# 5 Class, True Pos 3313721.0, False Pos 190401.0, False Neg 180078.0, Dice score 0.95
# 6 Class, True Pos 62426.0, False Pos 21689.0, False Neg 31760.0, Dice score 0.70
# 7 Class, True Pos 124529.0, False Pos 12468.0, False Neg 14993.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 89497.0, False Pos 5589.0, False Neg 24886.0, Dice score 0.85
# 10 Class, True Pos 2592757.0, False Pos 101957.0, False Neg 132372.0, Dice score 0.96
# 11 Class, True Pos 153439.0, False Pos 27741.0, False Neg 22522.0, Dice score 0.86
# ----------
# Dice Score: 0.8196
# ----------
#
# EPOCH 21 of 50
#
# Training Loss: 0.2336
# 0 Class, True Pos 51337628.0, False Pos 1921549.0, False Neg 1806484.0, Dice score 0.96
# 1 Class, True Pos 10570309.0, False Pos 403715.0, False Neg 350539.0, Dice score 0.97
# 2 Class, True Pos 4900600.0, False Pos 549775.0, False Neg 452101.0, Dice score 0.91
# 3 Class, True Pos 2211111.0, False Pos 195834.0, False Neg 266249.0, Dice score 0.91
# 4 Class, True Pos 19243770.0, False Pos 759216.0, False Neg 816095.0, Dice score 0.96
# 5 Class, True Pos 13067319.0, False Pos 573484.0, False Neg 628779.0, Dice score 0.96
# 6 Class, True Pos 321718.0, False Pos 89195.0, False Neg 96901.0, Dice score 0.78
# 7 Class, True Pos 555466.0, False Pos 40821.0, False Neg 57836.0, Dice score 0.92
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 459465.0, False Pos 23366.0, False Neg 28051.0, Dice score 0.95
# 10 Class, True Pos 9172766.0, False Pos 266933.0, False Neg 318702.0, Dice score 0.97
# 11 Class, True Pos 538688.0, False Pos 24799.0, False Neg 22758.0, Dice score 0.96
# Vaildation Loss: 0.2616
# 0 Class, True Pos 12610966.0, False Pos 562327.0, False Neg 514537.0, Dice score 0.96
# 1 Class, True Pos 2430066.0, False Pos 128024.0, False Neg 106838.0, Dice score 0.95
# 2 Class, True Pos 1194954.0, False Pos 167412.0, False Neg 138180.0, Dice score 0.89
# 3 Class, True Pos 477226.0, False Pos 51119.0, False Neg 86550.0, Dice score 0.87
# 4 Class, True Pos 4718789.0, False Pos 214944.0, False Neg 223855.0, Dice score 0.96
# 5 Class, True Pos 3310014.0, False Pos 161500.0, False Neg 183785.0, Dice score 0.95
# 6 Class, True Pos 64690.0, False Pos 23212.0, False Neg 29496.0, Dice score 0.71
# 7 Class, True Pos 124006.0, False Pos 12200.0, False Neg 15516.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 92550.0, False Pos 6195.0, False Neg 21833.0, Dice score 0.87
# 10 Class, True Pos 2627572.0, False Pos 99729.0, False Neg 97557.0, Dice score 0.96
# 11 Class, True Pos 146303.0, False Pos 21642.0, False Neg 29658.0, Dice score 0.85
# ----------
# Dice Score: 0.8227
# ----------
#
# EPOCH 22 of 50
#
# Training Loss: 0.2349
# 0 Class, True Pos 51366564.0, False Pos 1904364.0, False Neg 1777552.0, Dice score 0.97
# 1 Class, True Pos 10579545.0, False Pos 402395.0, False Neg 341303.0, Dice score 0.97
# 2 Class, True Pos 4905297.0, False Pos 521608.0, False Neg 447404.0, Dice score 0.91
# 3 Class, True Pos 2222600.0, False Pos 196054.0, False Neg 254760.0, Dice score 0.91
# 4 Class, True Pos 19244220.0, False Pos 773076.0, False Neg 815644.0, Dice score 0.96
# 5 Class, True Pos 13069629.0, False Pos 591968.0, False Neg 626469.0, Dice score 0.96
# 6 Class, True Pos 324348.0, False Pos 92456.0, False Neg 94271.0, Dice score 0.78
# 7 Class, True Pos 555722.0, False Pos 39571.0, False Neg 57580.0, Dice score 0.92
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 459353.0, False Pos 23183.0, False Neg 28163.0, Dice score 0.95
# 10 Class, True Pos 9156546.0, False Pos 236518.0, False Neg 334922.0, Dice score 0.97
# 11 Class, True Pos 537350.0, False Pos 25163.0, False Neg 24096.0, Dice score 0.96
# Vaildation Loss: 0.2724
# 0 Class, True Pos 12521975.0, False Pos 547552.0, False Neg 603528.0, Dice score 0.96
# 1 Class, True Pos 2437523.0, False Pos 163139.0, False Neg 99381.0, Dice score 0.95
# 2 Class, True Pos 1208886.0, False Pos 213302.0, False Neg 124248.0, Dice score 0.88
# 3 Class, True Pos 493183.0, False Pos 84483.0, False Neg 70593.0, Dice score 0.86
# 4 Class, True Pos 4678227.0, False Pos 226114.0, False Neg 264417.0, Dice score 0.95
# 5 Class, True Pos 3273150.0, False Pos 176552.0, False Neg 220649.0, Dice score 0.94
# 6 Class, True Pos 60439.0, False Pos 18142.0, False Neg 33747.0, Dice score 0.70
# 7 Class, True Pos 118996.0, False Pos 9617.0, False Neg 20526.0, Dice score 0.89
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 78920.0, False Pos 5216.0, False Neg 35463.0, Dice score 0.80
# 10 Class, True Pos 2640596.0, False Pos 131888.0, False Neg 84533.0, Dice score 0.96
# 11 Class, True Pos 141971.0, False Pos 15569.0, False Neg 33990.0, Dice score 0.85
# ----------
# ----------
#
# EPOCH 23 of 50
#
# Training Loss: 0.2338
# 0 Class, True Pos 51392108.0, False Pos 1825225.0, False Neg 1751980.0, Dice score 0.97
# 1 Class, True Pos 10587331.0, False Pos 390478.0, False Neg 333517.0, Dice score 0.97
# 2 Class, True Pos 4919598.0, False Pos 521599.0, False Neg 433103.0, Dice score 0.91
# 3 Class, True Pos 2229839.0, False Pos 192909.0, False Neg 247521.0, Dice score 0.91
# 4 Class, True Pos 19239344.0, False Pos 744085.0, False Neg 820521.0, Dice score 0.96
# 5 Class, True Pos 13085433.0, False Pos 582162.0, False Neg 610665.0, Dice score 0.96
# 6 Class, True Pos 322473.0, False Pos 85248.0, False Neg 96146.0, Dice score 0.78
# 7 Class, True Pos 553369.0, False Pos 41538.0, False Neg 59933.0, Dice score 0.92
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 461860.0, False Pos 22449.0, False Neg 25656.0, Dice score 0.95
# 10 Class, True Pos 9220564.0, False Pos 246356.0, False Neg 270904.0, Dice score 0.97
# 11 Class, True Pos 539526.0, False Pos 24009.0, False Neg 21920.0, Dice score 0.96
# Vaildation Loss: 0.2808
# 0 Class, True Pos 12584824.0, False Pos 522795.0, False Neg 540679.0, Dice score 0.96
# 1 Class, True Pos 2441972.0, False Pos 144691.0, False Neg 94932.0, Dice score 0.95
# 2 Class, True Pos 1186901.0, False Pos 151003.0, False Neg 146233.0, Dice score 0.89
# 3 Class, True Pos 480862.0, False Pos 57214.0, False Neg 82914.0, Dice score 0.87
# 4 Class, True Pos 4750050.0, False Pos 245508.0, False Neg 192594.0, Dice score 0.96
# 5 Class, True Pos 3302678.0, False Pos 160613.0, False Neg 191121.0, Dice score 0.95
# 6 Class, True Pos 58900.0, False Pos 15743.0, False Neg 35286.0, Dice score 0.70
# 7 Class, True Pos 123691.0, False Pos 11651.0, False Neg 15831.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# ...
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 470087.0, False Pos 11480.0, False Neg 17429.0, Dice score 0.97
# 10 Class, True Pos 9310026.0, False Pos 191990.0, False Neg 181442.0, Dice score 0.98
# 11 Class, True Pos 544783.0, False Pos 12368.0, False Neg 16663.0, Dice score 0.97
# Vaildation Loss: 0.2618
# 0 Class, True Pos 12674807.0, False Pos 522851.0, False Neg 450696.0, Dice score 0.96
# 1 Class, True Pos 2440010.0, False Pos 123573.0, False Neg 96894.0, Dice score 0.96
# 2 Class, True Pos 1199999.0, False Pos 144400.0, False Neg 133135.0, Dice score 0.90
# 3 Class, True Pos 495724.0, False Pos 63278.0, False Neg 68052.0, Dice score 0.88
# 4 Class, True Pos 4729515.0, False Pos 168519.0, False Neg 213129.0, Dice score 0.96
# 5 Class, True Pos 3329044.0, False Pos 144062.0, False Neg 164755.0, Dice score 0.96
# 6 Class, True Pos 64732.0, False Pos 20621.0, False Neg 29454.0, Dice score 0.72
# 7 Class, True Pos 125409.0, False Pos 12368.0, False Neg 14113.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 83010.0, False Pos 4335.0, False Neg 31373.0, Dice score 0.82
# 10 Class, True Pos 2637207.0, False Pos 96072.0, False Neg 87922.0, Dice score 0.97
# 11 Class, True Pos 149448.0, False Pos 16456.0, False Neg 26513.0, Dice score 0.87
# ----------
# ----------
#
# EPOCH 44 of 50
#
# Training Loss: 0.2140
# 0 Class, True Pos 51757408.0, False Pos 1279002.0, False Neg 1386701.0, Dice score 0.97
# 1 Class, True Pos 10655455.0, False Pos 339612.0, False Neg 265393.0, Dice score 0.97
# 2 Class, True Pos 5042764.0, False Pos 380922.0, False Neg 309937.0, Dice score 0.94
# 3 Class, True Pos 2304144.0, False Pos 131711.0, False Neg 173216.0, Dice score 0.94
# 4 Class, True Pos 19507038.0, False Pos 569262.0, False Neg 552833.0, Dice score 0.97
# 5 Class, True Pos 13265290.0, False Pos 424899.0, False Neg 430808.0, Dice score 0.97
# 6 Class, True Pos 347903.0, False Pos 71567.0, False Neg 70716.0, Dice score 0.83
# 7 Class, True Pos 568165.0, False Pos 33976.0, False Neg 45137.0, Dice score 0.93
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 468979.0, False Pos 12027.0, False Neg 18537.0, Dice score 0.97
# 10 Class, True Pos 9311497.0, False Pos 196561.0, False Neg 179971.0, Dice score 0.98
# 11 Class, True Pos 546330.0, False Pos 13018.0, False Neg 15116.0, Dice score 0.97
# Vaildation Loss: 0.2697
# 0 Class, True Pos 12653872.0, False Pos 503527.0, False Neg 471631.0, Dice score 0.96
# 1 Class, True Pos 2443816.0, False Pos 127218.0, False Neg 93088.0, Dice score 0.96
# 2 Class, True Pos 1196848.0, False Pos 138174.0, False Neg 136286.0, Dice score 0.90
# 3 Class, True Pos 496772.0, False Pos 62877.0, False Neg 67004.0, Dice score 0.88
# 4 Class, True Pos 4728874.0, False Pos 171071.0, False Neg 213770.0, Dice score 0.96
# 5 Class, True Pos 3342096.0, False Pos 158810.0, False Neg 151703.0, Dice score 0.96
# 6 Class, True Pos 61987.0, False Pos 16771.0, False Neg 32199.0, Dice score 0.72
# 7 Class, True Pos 124265.0, False Pos 11647.0, False Neg 15257.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 87833.0, False Pos 3329.0, False Neg 26550.0, Dice score 0.85
# 10 Class, True Pos 2646923.0, False Pos 106741.0, False Neg 78206.0, Dice score 0.97
# 11 Class, True Pos 147275.0, False Pos 14714.0, False Neg 28686.0, Dice score 0.87
# ----------
# Dice Score: 0.8275
# ----------
#
# EPOCH 45 of 50
#
# Training Loss: 0.2170
# 0 Class, True Pos 51792000.0, False Pos 1261875.0, False Neg 1352102.0, Dice score 0.98
# 1 Class, True Pos 10668170.0, False Pos 335849.0, False Neg 252678.0, Dice score 0.97
# 2 Class, True Pos 5055471.0, False Pos 376323.0, False Neg 297230.0, Dice score 0.94
# 3 Class, True Pos 2307843.0, False Pos 128604.0, False Neg 169517.0, Dice score 0.94
# 4 Class, True Pos 19505956.0, False Pos 534040.0, False Neg 553917.0, Dice score 0.97
# 5 Class, True Pos 13282708.0, False Pos 418411.0, False Neg 413390.0, Dice score 0.97
# 6 Class, True Pos 348769.0, False Pos 68222.0, False Neg 69850.0, Dice score 0.83
# 7 Class, True Pos 569965.0, False Pos 34570.0, False Neg 43337.0, Dice score 0.94
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 470970.0, False Pos 11917.0, False Neg 16546.0, Dice score 0.97
# 10 Class, True Pos 9304714.0, False Pos 191867.0, False Neg 186754.0, Dice score 0.98
# 11 Class, True Pos 546467.0, False Pos 12814.0, False Neg 14979.0, Dice score 0.98
# Vaildation Loss: 0.2632
# 0 Class, True Pos 12667027.0, False Pos 531138.0, False Neg 458476.0, Dice score 0.96
# 1 Class, True Pos 2432167.0, False Pos 107629.0, False Neg 104737.0, Dice score 0.96
# 2 Class, True Pos 1194938.0, False Pos 142956.0, False Neg 138196.0, Dice score 0.89
# 3 Class, True Pos 494512.0, False Pos 58615.0, False Neg 69264.0, Dice score 0.89
# 4 Class, True Pos 4739244.0, False Pos 183681.0, False Neg 203400.0, Dice score 0.96
# 5 Class, True Pos 3321400.0, False Pos 133850.0, False Neg 172399.0, Dice score 0.96
# 6 Class, True Pos 65968.0, False Pos 21537.0, False Neg 28218.0, Dice score 0.73
# 7 Class, True Pos 124377.0, False Pos 11783.0, False Neg 15145.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 86839.0, False Pos 4537.0, False Neg 27544.0, Dice score 0.84
# 10 Class, True Pos 2648346.0, False Pos 114042.0, False Neg 76783.0, Dice score 0.97
# 11 Class, True Pos 146870.0, False Pos 13984.0, False Neg 29091.0, Dice score 0.87
# ----------
# ----------
#
# EPOCH 46 of 50
#
# Training Loss: 0.2240
# 0 Class, True Pos 51797548.0, False Pos 1332162.0, False Neg 1346564.0, Dice score 0.97
# 1 Class, True Pos 10666871.0, False Pos 340674.0, False Neg 253977.0, Dice score 0.97
# 2 Class, True Pos 5039178.0, False Pos 369819.0, False Neg 313523.0, Dice score 0.94
# 3 Class, True Pos 2308372.0, False Pos 127437.0, False Neg 168988.0, Dice score 0.94
# 4 Class, True Pos 19454146.0, False Pos 542470.0, False Neg 605717.0, Dice score 0.97
# 5 Class, True Pos 13263960.0, False Pos 412914.0, False Neg 432138.0, Dice score 0.97
# 6 Class, True Pos 348341.0, False Pos 69761.0, False Neg 70278.0, Dice score 0.83
# 7 Class, True Pos 569520.0, False Pos 33175.0, False Neg 43782.0, Dice score 0.94
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 470013.0, False Pos 11045.0, False Neg 17503.0, Dice score 0.97
# 10 Class, True Pos 9321812.0, False Pos 191705.0, False Neg 169656.0, Dice score 0.98
# 11 Class, True Pos 544476.0, False Pos 12126.0, False Neg 16970.0, Dice score 0.97
# Vaildation Loss: 0.2678
# 0 Class, True Pos 12687252.0, False Pos 559511.0, False Neg 438251.0, Dice score 0.96
# 1 Class, True Pos 2429608.0, False Pos 105361.0, False Neg 107296.0, Dice score 0.96
# 2 Class, True Pos 1192810.0, False Pos 134421.0, False Neg 140324.0, Dice score 0.90
# 3 Class, True Pos 498885.0, False Pos 66080.0, False Neg 64891.0, Dice score 0.88
# 4 Class, True Pos 4707975.0, False Pos 155333.0, False Neg 234669.0, Dice score 0.96
# 5 Class, True Pos 3337890.0, False Pos 155194.0, False Neg 155909.0, Dice score 0.96
# 6 Class, True Pos 64612.0, False Pos 20023.0, False Neg 29574.0, Dice score 0.72
# 7 Class, True Pos 124558.0, False Pos 11517.0, False Neg 14964.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 88021.0, False Pos 4494.0, False Neg 26362.0, Dice score 0.85
# 10 Class, True Pos 2642168.0, False Pos 103920.0, False Neg 82961.0, Dice score 0.97
# 11 Class, True Pos 145176.0, False Pos 10631.0, False Neg 30785.0, Dice score 0.88
# ----------
# Dice Score: 0.8279
# ----------
#
# EPOCH 47 of 50
#
# Training Loss: 0.2184
# 0 Class, True Pos 51763768.0, False Pos 1321284.0, False Neg 1380332.0, Dice score 0.97
# 1 Class, True Pos 10671992.0, False Pos 337557.0, False Neg 248856.0, Dice score 0.97
# 2 Class, True Pos 5046066.0, False Pos 376077.0, False Neg 306635.0, Dice score 0.94
# 3 Class, True Pos 2310938.0, False Pos 129396.0, False Neg 166422.0, Dice score 0.94
# 4 Class, True Pos 19490528.0, False Pos 549388.0, False Neg 569336.0, Dice score 0.97
# 5 Class, True Pos 13275990.0, False Pos 437585.0, False Neg 420108.0, Dice score 0.97
# 6 Class, True Pos 346239.0, False Pos 69865.0, False Neg 72380.0, Dice score 0.83
# 7 Class, True Pos 568969.0, False Pos 33381.0, False Neg 44333.0, Dice score 0.94
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 469292.0, False Pos 11739.0, False Neg 18224.0, Dice score 0.97
# 10 Class, True Pos 9268064.0, False Pos 190289.0, False Neg 223404.0, Dice score 0.98
# 11 Class, True Pos 546358.0, False Pos 12749.0, False Neg 15088.0, Dice score 0.98
# Vaildation Loss: 0.2664
# 0 Class, True Pos 12696234.0, False Pos 559718.0, False Neg 429269.0, Dice score 0.96
# 1 Class, True Pos 2433987.0, False Pos 109848.0, False Neg 102917.0, Dice score 0.96
# 2 Class, True Pos 1192147.0, False Pos 133698.0, False Neg 140987.0, Dice score 0.90
# 3 Class, True Pos 496411.0, False Pos 62528.0, False Neg 67365.0, Dice score 0.88
# 4 Class, True Pos 4734980.0, False Pos 174664.0, False Neg 207664.0, Dice score 0.96
# 5 Class, True Pos 3309342.0, False Pos 124421.0, False Neg 184457.0, Dice score 0.96
# 6 Class, True Pos 64147.0, False Pos 19151.0, False Neg 30039.0, Dice score 0.72
# 7 Class, True Pos 123678.0, False Pos 10610.0, False Neg 15844.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 85361.0, False Pos 3611.0, False Neg 29022.0, Dice score 0.84
# 10 Class, True Pos 2644788.0, False Pos 107480.0, False Neg 80341.0, Dice score 0.97
# 11 Class, True Pos 146138.0, False Pos 12498.0, False Neg 29823.0, Dice score 0.87
# ----------
# ----------
#
# EPOCH 48 of 50
#
# Training Loss: 0.2109
# 0 Class, True Pos 51801568.0, False Pos 1202752.0, False Neg 1342539.0, Dice score 0.98
# 1 Class, True Pos 10675597.0, False Pos 334176.0, False Neg 245251.0, Dice score 0.97
# 2 Class, True Pos 5062113.0, False Pos 366230.0, False Neg 290588.0, Dice score 0.94
# 3 Class, True Pos 2313541.0, False Pos 123738.0, False Neg 163819.0, Dice score 0.94
# 4 Class, True Pos 19532008.0, False Pos 540750.0, False Neg 527861.0, Dice score 0.97
# 5 Class, True Pos 13298693.0, False Pos 407904.0, False Neg 397405.0, Dice score 0.97
# 6 Class, True Pos 349730.0, False Pos 66667.0, False Neg 68889.0, Dice score 0.84
# 7 Class, True Pos 569596.0, False Pos 32449.0, False Neg 43706.0, Dice score 0.94
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 472361.0, False Pos 12262.0, False Neg 15155.0, Dice score 0.97
# 10 Class, True Pos 9319216.0, False Pos 187436.0, False Neg 172252.0, Dice score 0.98
# 11 Class, True Pos 546771.0, False Pos 11968.0, False Neg 14675.0, Dice score 0.98
# Vaildation Loss: 0.2706
# 0 Class, True Pos 12680133.0, False Pos 531644.0, False Neg 445370.0, Dice score 0.96
# 1 Class, True Pos 2435999.0, False Pos 110624.0, False Neg 100905.0, Dice score 0.96
# 2 Class, True Pos 1193158.0, False Pos 134863.0, False Neg 139976.0, Dice score 0.90
# 3 Class, True Pos 494286.0, False Pos 57909.0, False Neg 69490.0, Dice score 0.89
# 4 Class, True Pos 4744529.0, False Pos 182380.0, False Neg 198115.0, Dice score 0.96
# 5 Class, True Pos 3324870.0, False Pos 140001.0, False Neg 168929.0, Dice score 0.96
# 6 Class, True Pos 62499.0, False Pos 17412.0, False Neg 31687.0, Dice score 0.72
# 7 Class, True Pos 125466.0, False Pos 12405.0, False Neg 14056.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 88213.0, False Pos 4287.0, False Neg 26170.0, Dice score 0.85
# 10 Class, True Pos 2639841.0, False Pos 100948.0, False Neg 85288.0, Dice score 0.97
# 11 Class, True Pos 149045.0, False Pos 14928.0, False Neg 26916.0, Dice score 0.88
# ----------
# Dice Score: 0.8283
# ----------
#
# EPOCH 49 of 50
#
# Training Loss: 0.2128
# 0 Class, True Pos 51827400.0, False Pos 1193935.0, False Neg 1316713.0, Dice score 0.98
# 1 Class, True Pos 10677818.0, False Pos 327378.0, False Neg 243030.0, Dice score 0.97
# 2 Class, True Pos 5065673.0, False Pos 360923.0, False Neg 287028.0, Dice score 0.94
# 3 Class, True Pos 2318033.0, False Pos 120647.0, False Neg 159327.0, Dice score 0.94
# 4 Class, True Pos 19537034.0, False Pos 543647.0, False Neg 522828.0, Dice score 0.97
# 5 Class, True Pos 13294857.0, False Pos 402591.0, False Neg 401241.0, Dice score 0.97
# 6 Class, True Pos 350938.0, False Pos 65956.0, False Neg 67681.0, Dice score 0.84
# 7 Class, True Pos 569220.0, False Pos 32370.0, False Neg 44082.0, Dice score 0.94
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 471342.0, False Pos 10099.0, False Neg 16174.0, Dice score 0.97
# 10 Class, True Pos 9319326.0, False Pos 185570.0, False Neg 172142.0, Dice score 0.98
# 11 Class, True Pos 541269.0, False Pos 11499.0, False Neg 20177.0, Dice score 0.97
# Vaildation Loss: 0.2590
# 0 Class, True Pos 12669684.0, False Pos 508743.0, False Neg 455819.0, Dice score 0.96
# 1 Class, True Pos 2431867.0, False Pos 106651.0, False Neg 105037.0, Dice score 0.96
# 2 Class, True Pos 1204940.0, False Pos 148928.0, False Neg 128194.0, Dice score 0.90
# 3 Class, True Pos 495782.0, False Pos 60657.0, False Neg 67994.0, Dice score 0.89
# 4 Class, True Pos 4750165.0, False Pos 179431.0, False Neg 192479.0, Dice score 0.96
# 5 Class, True Pos 3329693.0, False Pos 139517.0, False Neg 164106.0, Dice score 0.96
# 6 Class, True Pos 64807.0, False Pos 20364.0, False Neg 29379.0, Dice score 0.72
# 7 Class, True Pos 124728.0, False Pos 12086.0, False Neg 14794.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 89848.0, False Pos 4706.0, False Neg 24535.0, Dice score 0.86
# 10 Class, True Pos 2643216.0, False Pos 104119.0, False Neg 81913.0, Dice score 0.97
# 11 Class, True Pos 143902.0, False Pos 11606.0, False Neg 32059.0, Dice score 0.87
# ----------
# Dice Score: 0.8285
# ----------
#
# EPOCH 50 of 50
#
# Training Loss: 0.2129
# 0 Class, True Pos 51841904.0, False Pos 1213713.0, False Neg 1302200.0, Dice score 0.98
# 1 Class, True Pos 10678399.0, False Pos 329051.0, False Neg 242449.0, Dice score 0.97
# 2 Class, True Pos 5061639.0, False Pos 357276.0, False Neg 291062.0, Dice score 0.94
# 3 Class, True Pos 2314889.0, False Pos 118150.0, False Neg 162471.0, Dice score 0.94
# 4 Class, True Pos 19520278.0, False Pos 515838.0, False Neg 539587.0, Dice score 0.97
# 5 Class, True Pos 13303770.0, False Pos 407028.0, False Neg 392328.0, Dice score 0.97
# 6 Class, True Pos 350990.0, False Pos 65866.0, False Neg 67629.0, Dice score 0.84
# 7 Class, True Pos 570920.0, False Pos 32567.0, False Neg 42382.0, Dice score 0.94
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 4192.0, Dice score 0.00
# 9 Class, True Pos 472074.0, False Pos 10495.0, False Neg 15442.0, Dice score 0.97
# 10 Class, True Pos 9318839.0, False Pos 183902.0, False Neg 172629.0, Dice score 0.98
# 11 Class, True Pos 546992.0, False Pos 12939.0, False Neg 14454.0, Dice score 0.98
# Vaildation Loss: 0.2654
# 0 Class, True Pos 12678397.0, False Pos 533645.0, False Neg 447106.0, Dice score 0.96
# 1 Class, True Pos 2434304.0, False Pos 114644.0, False Neg 102600.0, Dice score 0.96
# 2 Class, True Pos 1187458.0, False Pos 127406.0, False Neg 145676.0, Dice score 0.90
# 3 Class, True Pos 495015.0, False Pos 61139.0, False Neg 68761.0, Dice score 0.88
# 4 Class, True Pos 4749179.0, False Pos 183433.0, False Neg 193465.0, Dice score 0.96
# 5 Class, True Pos 3333861.0, False Pos 151763.0, False Neg 159938.0, Dice score 0.96
# 6 Class, True Pos 62648.0, False Pos 17308.0, False Neg 31538.0, Dice score 0.72
# 7 Class, True Pos 124898.0, False Pos 12008.0, False Neg 14624.0, Dice score 0.90
# 8 Class, True Pos 0.0, False Pos 0.0, False Neg 499.0, Dice score 0.00
# 9 Class, True Pos 85468.0, False Pos 3829.0, False Neg 28915.0, Dice score 0.84
# 10 Class, True Pos 2631634.0, False Pos 97532.0, False Neg 93495.0, Dice score 0.96
# 11 Class, True Pos 145254.0, False Pos 14617.0, False Neg 30707.0, Dice score 0.87
# ----------
# ----------

# %%
## load best model weights
model.load_state_dict(best_model_wts)
## save model
torch.save(model.state_dict(), '/mydrive/My Drive/Colab Notebooks/super_label_albunet.pt')

# %% [markdown]
# ## Test

# %%
# load test dataset
test_dataset=MICCAIDataset(data_path = "/mydrive/My Drive/Colab Notebooks/data/",data_type = "test", transform=None)
test_generator=DataLoader(test_dataset,shuffle=False,batch_size=4,num_workers=8)

# %%
# load model
model.load_state_dict(torch.load('/mydrive/My Drive/Colab Notebooks/super_label_albunet.pt'))
model.to(device)
print("Model loaded")
# Out:
# Model loaded

# %%
  final_dice = test(model,device,dice_loss,num_class,test_generator,test_dataset,writer)
# Out:
# Dice Score: 0.8307
# 0 Class, True Pos 16096912.0, False Pos 639520.0, Flase Neg 623557.0
# 1 Class, True Pos 3027490.0, False Pos 117314.0, Flase Neg 128939.0
# 2 Class, True Pos 1635486.0, False Pos 207880.0, Flase Neg 204670.0
# 3 Class, True Pos 760960.0, False Pos 116953.0, Flase Neg 107302.0
# 4 Class, True Pos 6265518.0, False Pos 293634.0, Flase Neg 247285.0
# 5 Class, True Pos 4002759.0, False Pos 172523.0, Flase Neg 207749.0
# 6 Class, True Pos 95271.0, False Pos 28616.0, Flase Neg 36459.0
# 7 Class, True Pos 139076.0, False Pos 16616.0, Flase Neg 23715.0
# 8 Class, True Pos 0.0, False Pos 0.0, Flase Neg 338.0
# 9 Class, True Pos 129091.0, False Pos 10087.0, Flase Neg 22883.0
# 10 Class, True Pos 2559640.0, False Pos 92786.0, Flase Neg 85848.0
# 11 Class, True Pos 192543.0, False Pos 17565.0, Flase Neg 24749.0
# ----------

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# # Pretraining
